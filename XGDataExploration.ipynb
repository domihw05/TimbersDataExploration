# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Data Sets/american_soccer_analysis_mls_xgoals_players_2025-02-19.csv')

# %%
df[df['Team'] == 'POR'].sort_values('xPA',ascending = False)
# Out:
#      Unnamed: 0              Player Team  Season Position  Minutes  Shots  \
# 20          NaN         Felipe Mora  POR    2024       ST     2109     65
# 13          NaN  Jonathan Rodríguez  POR    2024        W     2723     94
# 4           NaN             Evander  POR    2024       AM     2780     96
# 46          NaN     Santiago Moreno  POR    2024        W     2738     61
# 131         NaN              Antony  POR    2024        W     2141     38
# 140         NaN       Juan Mosquera  POR    2024       FB     3101     20
# 441         NaN       Miguel Araujo  POR    2024       CB     1785      9
# 305         NaN     Dairon Asprilla  POR    2024       ST      818      9
# 547         NaN       Dario Zuparic  POR    2024       CB     2533      5
# 553         NaN        Kamal Miller  POR    2024       CB     2229      7
# 296         NaN         David Ayala  POR    2024       DM     1664     15
# 544         NaN       Nathan Fogaça  POR    2024       ST      285      8
# ...
